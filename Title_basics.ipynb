# %% [markdown]
# Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load Data

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
title_basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics_url2="https://datasets.imdbws.com/title.akas.tsv.gz"
title_akas = pd.read_csv(basics_url2, sep='\t', low_memory=False)

# %%
basics_url3="https://datasets.imdbws.com/title.ratings.tsv.gz"
title_ratings = pd.read_csv(basics_url3, sep='\t', low_memory=False)

# %% [markdown]
# Filtering/Cleaning Data

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics.duplicated().sum()
# Out:
# 0

# %%
title_basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
title_basics.dropna(subset=['primaryTitle', 'originalTitle', 'genres'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %% [markdown]
# Replace "\N" with np.nan

# %%
title_basics.replace({'\\N':np.nan},inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11128\3947680042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   title_basics.replace({'\\N':np.nan},inplace=True)

# %%
title_basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear               0
# endYear           9496807
# runtimeMinutes    6795237
# genres             434061
# dtype: int64

# %%
title_basics = title_basics.drop(columns=['endYear'])
title_basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear               0
# runtimeMinutes    6795237
# genres             434061
# dtype: int64

# %%
title_basics.dropna(subset=['runtimeMinutes'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst                0
# titleType             0
# primaryTitle          0
# originalTitle         0
# isAdult               0
# startYear             0
# runtimeMinutes        0
# genres            75479
# dtype: int64

# %%
title_basics.dropna(subset=['genres'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %% [markdown]
# Eliminate movies that include "Documentary" in genre

# %%
#Eliminate movies that include "Documentary" in genre
is_documentary = title_basics['genres'].str.contains('documentary',case=False)
title_basics= title_basics[~is_documentary]

# %%
title_basics
# Out:
#             tconst  titleType                     primaryTitle  \
# 1        tt0000002      short           Le clown et ses chiens
# 2        tt0000003      short                   Pauvre Pierrot
# 3        tt0000004      short                      Un bon bock
# 4        tt0000005      short                 Blacksmith Scene
# 5        tt0000006      short                Chinese Opium Den
# ...            ...        ...                              ...
# 9599071  tt9916692    tvMovie  Teatroteka: Czlowiek bez twarzy
# 9599104  tt9916766  tvEpisode                   Episode #10.15
# 9599139  tt9916840  tvEpisode       Horrid Henry's Comic Caper
# 9599146  tt9916856      short                         The Wind
# 9599147  tt9916880  tvEpisode        Horrid Henry Knows It All
#
#                            originalTitle isAdult startYear runtimeMinutes  \
# 1                 Le clown et ses chiens       0      1892              5
# 2                         Pauvre Pierrot       0      1892              4
# 3                            Un bon bock       0      1892             12
# 4                       Blacksmith Scene       0      1893              1
# 5                      Chinese Opium Den       0      1894              1
# ...                                  ...     ...       ...            ...
# 9599071  Teatroteka: Czlowiek bez twarzy       0      2015             66
# 9599104                   Episode #10.15       0      2019             43
# 9599139       Horrid Henry's Comic Caper       0      2014             11
# 9599146                         The Wind       0      2015             27
# 9599147        Horrid Henry Knows It All       0      2014             10
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9599071                        Drama
# 9599104  Family,Game-Show,Reality-TV
# 9599139   Adventure,Animation,Comedy
# 9599146                        Short
# 9599147   Adventure,Animation,Comedy
#
# [2330866 rows x 8 columns]

# %% [markdown]
# Keep only US movies

# %%
keepers =title_basics['tconst'].isin(title_akas['titleId'])
keepers
# Out:
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
#            ...
# 9599071     True
# 9599104     True
# 9599139    False
# 9599146     True
# 9599147    False
# Name: tconst, Length: 2330866, dtype: bool

# %%
title_basics = title_basics[keepers]
title_basics
# Out:
#             tconst  titleType                     primaryTitle  \
# 1        tt0000002      short           Le clown et ses chiens
# 2        tt0000003      short                   Pauvre Pierrot
# 3        tt0000004      short                      Un bon bock
# 4        tt0000005      short                 Blacksmith Scene
# 5        tt0000006      short                Chinese Opium Den
# ...            ...        ...                              ...
# 9599034  tt9916610      short                      Private Eye
# 9599036  tt9916616      short                           Terror
# 9599071  tt9916692    tvMovie  Teatroteka: Czlowiek bez twarzy
# 9599104  tt9916766  tvEpisode                   Episode #10.15
# 9599146  tt9916856      short                         The Wind
#
#                            originalTitle isAdult startYear runtimeMinutes  \
# 1                 Le clown et ses chiens       0      1892              5
# 2                         Pauvre Pierrot       0      1892              4
# 3                            Un bon bock       0      1892             12
# 4                       Blacksmith Scene       0      1893              1
# 5                      Chinese Opium Den       0      1894              1
# ...                                  ...     ...       ...            ...
# 9599034                      Private Eye       0      2019             22
# 9599036                           Terror       0        \N             13
# 9599071  Teatroteka: Czlowiek bez twarzy       0      2015             66
# 9599104                   Episode #10.15       0      2019             43
# 9599146                         The Wind       0      2015             27
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9599034         Drama,Mystery,Sci-Fi
# 9599036                  Drama,Short
# 9599071                        Drama
# 9599104  Family,Game-Show,Reality-TV
# 9599146                        Short
#
# [1914944 rows x 8 columns]

# %% [markdown]
# keep only titleType==Movie

# %%
#Eliminate movies that include "short" in genre
is_short = title_basics['titleType'].str.contains('short',case=False)
title_basics= title_basics[~is_short]

#Eliminate movies that include "tvEpisode	" in genre
is_tvEpisode = title_basics['titleType'].str.contains('tvEpisode',case=False)
title_basics= title_basics[~is_tvEpisode]

#Eliminate movies that include "tvSeries" in genre
is_tvSeries = title_basics['titleType'].str.contains('tvSeries',case=False)
title_basics= title_basics[~is_tvSeries]

#Eliminate movies that include "tvMovie" in genre
is_tvMovie = title_basics['titleType'].str.contains('tvMovie',case=False)
title_basics= title_basics[~is_tvMovie]

#Eliminate movies that include "video" in genre
is_video = title_basics['titleType'].str.contains('video',case=False)
title_basics= title_basics[~is_video]

# %%
title_basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 930      tt0000941     movie                  Locura de amor
# ...            ...       ...                             ...
# 9598821  tt9916170     movie                   The Rehearsal
# 9598830  tt9916190     movie                       Safeguard
# 9598869  tt9916270     movie        Il talento del calabrone
# 9598914  tt9916362     movie                           Coven
# 9598998  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult startYear runtimeMinutes  \
# 8                            Miss Jerry       0      1894             45
# 570         The Story of the Kelly Gang       0      1906             70
# 587                   L'enfant prodigue       0      1907             90
# 672      The Fairylogue and Radio-Plays       0      1908            120
# 930                      Locura de amor       0      1909             45
# ...                                 ...     ...       ...            ...
# 9598821                        O Ensaio       0      2019             51
# 9598830                       Safeguard       0      2020             95
# 9598869        Il talento del calabrone       0      2020             84
# 9598914                        Akelarre       0      2020             92
# 9598998             Kuambil Lagi Hatiku       0      2019            123
#
#                              genres
# 8                           Romance
# 570      Action,Adventure,Biography
# 587                           Drama
# 672               Adventure,Fantasy
# 930                           Drama
# ...                             ...
# 9598821                       Drama
# 9598830   Action,Adventure,Thriller
# 9598869                    Thriller
# 9598914               Drama,History
# 9598998                       Drama
#
# [311878 rows x 8 columns]

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311878 entries, 0 to 311877
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          311878 non-null  object
#  1   titleType       311878 non-null  object
#  2   primaryTitle    311878 non-null  object
#  3   originalTitle   311878 non-null  object
#  4   isAdult         311878 non-null  int64
#  5   startYear       307161 non-null  float64
#  6   runtimeMinutes  311878 non-null  int64
#  7   genres          311878 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 19.0+ MB

# %% [markdown]
# keep startYear 2000-2022

# %%
title_basics['startYear'] = title_basics['startYear'].astype(float)
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311878 entries, 0 to 311877
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          311878 non-null  object
#  1   titleType       311878 non-null  object
#  2   primaryTitle    311878 non-null  object
#  3   originalTitle   311878 non-null  object
#  4   isAdult         311878 non-null  int64
#  5   startYear       307161 non-null  float64
#  6   runtimeMinutes  311878 non-null  int64
#  7   genres          311878 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 19.0+ MB

# %%
keepers =title_basics['startYear'] >= 2000
keepers
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 311873     True
# 311874     True
# 311875     True
# 311876     True
# 311877     True
# Name: startYear, Length: 311878, dtype: bool

# %%
title_basics = title_basics[keepers]
title_basics
# Out:
#            tconst titleType  \
# 18892   tt0035423     movie
# 38136   tt0062336     movie
# 42536   tt0069049     movie
# 48914   tt0079644     movie
# 54156   tt0088751     movie
# ...           ...       ...
# 311873  tt9916170     movie
# 311874  tt9916190     movie
# 311875  tt9916270     movie
# 311876  tt9916362     movie
# 311877  tt9916538     movie
#
#                                              primaryTitle  \
# 18892                                      Kate & Leopold
# 38136   The Tango of the Widower and Its Distorting Mi...
# 42536                          The Other Side of the Wind
# 48914                                       November 1828
# 54156                                   The Naked Monster
# ...                                                   ...
# 311873                                      The Rehearsal
# 311874                                          Safeguard
# 311875                           Il talento del calabrone
# 311876                                              Coven
# 311877                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 18892                              Kate & Leopold        0     2001.0
# 38136   El tango del viudo y su espejo deformante        0     2020.0
# 42536                  The Other Side of the Wind        0     2018.0
# 48914                               November 1828        0     2001.0
# 54156                           The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 311873                                   O Ensaio        0     2019.0
# 311874                                  Safeguard        0     2020.0
# 311875                   Il talento del calabrone        0     2020.0
# 311876                                   Akelarre        0     2020.0
# 311877                        Kuambil Lagi Hatiku        0     2019.0
#
#         runtimeMinutes                     genres
# 18892              118     Comedy,Fantasy,Romance
# 38136               70                      Drama
# 42536              122                      Drama
# 48914              140                  Drama,War
# 54156              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 311873              51                      Drama
# 311874              95  Action,Adventure,Thriller
# 311875              84                   Thriller
# 311876              92              Drama,History
# 311877             123                      Drama
#
# [166014 rows x 8 columns]

# %%
## Save current dataframe to file.
title_basics.to_csv("title_basics.csv.gz",compression='gzip',index=False)
