# %% [markdown]
# Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load Data

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
title_basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics_url2="https://datasets.imdbws.com/title.akas.tsv.gz"
title_akas = pd.read_csv(basics_url2, sep='\t', low_memory=False)

# %%
basics_url3="https://datasets.imdbws.com/title.ratings.tsv.gz"
title_ratings = pd.read_csv(basics_url3, sep='\t', low_memory=False)

# %% [markdown]
# Filtering/Cleaning Data

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics.duplicated().sum()
# Out:
# 0

# %%
title_basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
title_basics.dropna(subset=['primaryTitle', 'originalTitle', 'genres'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %% [markdown]
# Replace "\N" with np.nan

# %%
title_basics['endYear'] = title_basics['endYear'].replace({'\\N':np.nan})
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9582800  tt9916848  tvEpisode              Episode #3.17
# 9582801  tt9916850  tvEpisode              Episode #3.19
# 9582802  tt9916852  tvEpisode              Episode #3.20
# 9582803  tt9916856      short                   The Wind
# 9582804  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9582800              Episode #3.17       0      2010     NaN             \N
# 9582801              Episode #3.19       0      2010     NaN             \N
# 9582802              Episode #3.20       0      2010     NaN             \N
# 9582803                   The Wind       0      2015     NaN             27
# 9582804  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9582800         Action,Drama,Family
# 9582801         Action,Drama,Family
# 9582802         Action,Drama,Family
# 9582803                       Short
# 9582804  Adventure,Animation,Comedy
#
# [9582784 rows x 9 columns]

# %%
title_basics['runtimeMinutes'] = title_basics['runtimeMinutes'].replace({'\\N':np.nan})
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9582800  tt9916848  tvEpisode              Episode #3.17
# 9582801  tt9916850  tvEpisode              Episode #3.19
# 9582802  tt9916852  tvEpisode              Episode #3.20
# 9582803  tt9916856      short                   The Wind
# 9582804  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9582800              Episode #3.17       0      2010     NaN            NaN
# 9582801              Episode #3.19       0      2010     NaN            NaN
# 9582802              Episode #3.20       0      2010     NaN            NaN
# 9582803                   The Wind       0      2015     NaN             27
# 9582804  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9582800         Action,Drama,Family
# 9582801         Action,Drama,Family
# 9582802         Action,Drama,Family
# 9582803                       Short
# 9582804  Adventure,Animation,Comedy
#
# [9582784 rows x 9 columns]

# %%
title_basics['genres'] = title_basics['genres'].replace({'\\N':np.nan})
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9582800  tt9916848  tvEpisode              Episode #3.17
# 9582801  tt9916850  tvEpisode              Episode #3.19
# 9582802  tt9916852  tvEpisode              Episode #3.20
# 9582803  tt9916856      short                   The Wind
# 9582804  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9582800              Episode #3.17       0      2010     NaN            NaN
# 9582801              Episode #3.19       0      2010     NaN            NaN
# 9582802              Episode #3.20       0      2010     NaN            NaN
# 9582803                   The Wind       0      2015     NaN             27
# 9582804  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9582800         Action,Drama,Family
# 9582801         Action,Drama,Family
# 9582802         Action,Drama,Family
# 9582803                       Short
# 9582804  Adventure,Animation,Comedy
#
# [9582784 rows x 9 columns]

# %%
title_basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear               0
# endYear           9480723
# runtimeMinutes    6785364
# genres             433918
# dtype: int64

# %%
title_basics = title_basics.drop(columns=['endYear'])
title_basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear               0
# runtimeMinutes    6785364
# genres             433918
# dtype: int64

# %%
title_basics.dropna(subset=['runtimeMinutes'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst                0
# titleType             0
# primaryTitle          0
# originalTitle         0
# isAdult               0
# startYear             0
# runtimeMinutes        0
# genres            75411
# dtype: int64

# %%
title_basics.dropna(subset=['genres'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %% [markdown]
# Eliminate movies that include "Documentary" in genre

# %%
#Eliminate movies that include "Documentary" in genre
is_documentary = title_basics['genres'].str.contains('documentary',case=False)
title_basics= title_basics[~is_documentary]

# %%
title_basics
# Out:
#             tconst  titleType                     primaryTitle  \
# 1        tt0000002      short           Le clown et ses chiens
# 2        tt0000003      short                   Pauvre Pierrot
# 3        tt0000004      short                      Un bon bock
# 4        tt0000005      short                 Blacksmith Scene
# 5        tt0000006      short                Chinese Opium Den
# ...            ...        ...                              ...
# 9582728  tt9916692    tvMovie  Teatroteka: Czlowiek bez twarzy
# 9582761  tt9916766  tvEpisode                   Episode #10.15
# 9582796  tt9916840  tvEpisode       Horrid Henry's Comic Caper
# 9582803  tt9916856      short                         The Wind
# 9582804  tt9916880  tvEpisode        Horrid Henry Knows It All
#
#                            originalTitle isAdult startYear runtimeMinutes  \
# 1                 Le clown et ses chiens       0      1892              5
# 2                         Pauvre Pierrot       0      1892              4
# 3                            Un bon bock       0      1892             12
# 4                       Blacksmith Scene       0      1893              1
# 5                      Chinese Opium Den       0      1894              1
# ...                                  ...     ...       ...            ...
# 9582728  Teatroteka: Czlowiek bez twarzy       0      2015             66
# 9582761                   Episode #10.15       0      2019             43
# 9582796       Horrid Henry's Comic Caper       0      2014             11
# 9582803                         The Wind       0      2015             27
# 9582804        Horrid Henry Knows It All       0      2014             10
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9582728                        Drama
# 9582761  Family,Game-Show,Reality-TV
# 9582796   Adventure,Animation,Comedy
# 9582803                        Short
# 9582804   Adventure,Animation,Comedy
#
# [2325092 rows x 8 columns]

# %% [markdown]
# Keep only US movies

# %%
keepers =title_basics['tconst'].isin(title_akas['titleId'])
keepers
# Out:
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
#            ...
# 9582728     True
# 9582761     True
# 9582796    False
# 9582803     True
# 9582804    False
# Name: tconst, Length: 2325092, dtype: bool

# %%
title_basics = title_basics[keepers]
title_basics
# Out:
#             tconst  titleType                     primaryTitle  \
# 1        tt0000002      short           Le clown et ses chiens
# 2        tt0000003      short                   Pauvre Pierrot
# 3        tt0000004      short                      Un bon bock
# 4        tt0000005      short                 Blacksmith Scene
# 5        tt0000006      short                Chinese Opium Den
# ...            ...        ...                              ...
# 9582691  tt9916610      short                      Private Eye
# 9582693  tt9916616      short                           Terror
# 9582728  tt9916692    tvMovie  Teatroteka: Czlowiek bez twarzy
# 9582761  tt9916766  tvEpisode                   Episode #10.15
# 9582803  tt9916856      short                         The Wind
#
#                            originalTitle isAdult startYear runtimeMinutes  \
# 1                 Le clown et ses chiens       0      1892              5
# 2                         Pauvre Pierrot       0      1892              4
# 3                            Un bon bock       0      1892             12
# 4                       Blacksmith Scene       0      1893              1
# 5                      Chinese Opium Den       0      1894              1
# ...                                  ...     ...       ...            ...
# 9582691                      Private Eye       0      2019             22
# 9582693                           Terror       0        \N             13
# 9582728  Teatroteka: Czlowiek bez twarzy       0      2015             66
# 9582761                   Episode #10.15       0      2019             43
# 9582803                         The Wind       0      2015             27
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9582691         Drama,Mystery,Sci-Fi
# 9582693                  Drama,Short
# 9582728                        Drama
# 9582761  Family,Game-Show,Reality-TV
# 9582803                        Short
#
# [1909754 rows x 8 columns]

# %% [markdown]
# keep only titleType==Movie

# %%
#Eliminate movies that include "short" in genre
is_short = title_basics['titleType'].str.contains('short',case=False)
title_basics= title_basics[~is_short]

#Eliminate movies that include "tvEpisode	" in genre
is_tvEpisode = title_basics['titleType'].str.contains('tvEpisode',case=False)
title_basics= title_basics[~is_tvEpisode]

#Eliminate movies that include "tvSeries" in genre
is_tvSeries = title_basics['titleType'].str.contains('tvSeries',case=False)
title_basics= title_basics[~is_tvSeries]

#Eliminate movies that include "tvMovie" in genre
is_tvMovie = title_basics['titleType'].str.contains('tvMovie',case=False)
title_basics= title_basics[~is_tvMovie]

#Eliminate movies that include "video" in genre
is_video = title_basics['titleType'].str.contains('video',case=False)
title_basics= title_basics[~is_video]

# %%
title_basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 930      tt0000941     movie                  Locura de amor
# ...            ...       ...                             ...
# 9582478  tt9916170     movie                   The Rehearsal
# 9582487  tt9916190     movie                       Safeguard
# 9582526  tt9916270     movie        Il talento del calabrone
# 9582571  tt9916362     movie                           Coven
# 9582655  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult startYear runtimeMinutes  \
# 8                            Miss Jerry       0      1894             45
# 570         The Story of the Kelly Gang       0      1906             70
# 587                   L'enfant prodigue       0      1907             90
# 672      The Fairylogue and Radio-Plays       0      1908            120
# 930                      Locura de amor       0      1909             45
# ...                                 ...     ...       ...            ...
# 9582478                        O Ensaio       0      2019             51
# 9582487                       Safeguard       0      2020             95
# 9582526        Il talento del calabrone       0      2020             84
# 9582571                        Akelarre       0      2020             92
# 9582655             Kuambil Lagi Hatiku       0      2019            123
#
#                              genres
# 8                           Romance
# 570      Action,Adventure,Biography
# 587                           Drama
# 672               Adventure,Fantasy
# 930                           Drama
# ...                             ...
# 9582478                       Drama
# 9582487   Action,Adventure,Thriller
# 9582526                    Thriller
# 9582571               Drama,History
# 9582655                       Drama
#
# [311561 rows x 8 columns]

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311561 entries, 8 to 9582655
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          311561 non-null  object
#  1   titleType       311561 non-null  object
#  2   primaryTitle    311561 non-null  object
#  3   originalTitle   311561 non-null  object
#  4   isAdult         311561 non-null  object
#  5   startYear       311561 non-null  object
#  6   runtimeMinutes  311561 non-null  object
#  7   genres          311561 non-null  object
# dtypes: object(8)
# memory usage: 21.4+ MB

# %%
## Save current dataframe to file.
title_basics.to_csv("title_basics.csv.gz",compression='gzip',index=False)

# %%
title_basics = pd.read_csv("title_basics.csv.gz", low_memory = False)
title_basics.head()
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000009     movie                      Miss Jerry
# 1  tt0000574     movie     The Story of the Kelly Gang
# 2  tt0000591     movie                The Prodigal Son
# 3  tt0000679     movie  The Fairylogue and Radio-Plays
# 4  tt0000941     movie                  Locura de amor
#
#                     originalTitle  isAdult startYear  runtimeMinutes  \
# 0                      Miss Jerry        0      1894              45
# 1     The Story of the Kelly Gang        0      1906              70
# 2               L'enfant prodigue        0      1907              90
# 3  The Fairylogue and Radio-Plays        0      1908             120
# 4                  Locura de amor        0      1909              45
#
#                        genres
# 0                     Romance
# 1  Action,Adventure,Biography
# 2                       Drama
# 3           Adventure,Fantasy
# 4                       Drama
