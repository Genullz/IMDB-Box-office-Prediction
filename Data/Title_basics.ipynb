# %% [markdown]
# Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load Data

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
title_basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics_url2="https://datasets.imdbws.com/title.akas.tsv.gz"
title_akas = pd.read_csv(basics_url2, sep='\t', low_memory=False)

# %%
basics_url3="https://datasets.imdbws.com/title.ratings.tsv.gz"
title_ratings = pd.read_csv(basics_url3, sep='\t', low_memory=False)

# %% [markdown]
# Filtering/Cleaning Data

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics.duplicated().sum()
# Out:
# 0

# %%
title_basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
title_basics.dropna(subset=['primaryTitle', 'originalTitle', 'genres'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %% [markdown]
# Replace "\N" with np.nan

# %%
title_basics['endYear'] = title_basics['endYear'].replace({'\\N':np.nan})
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9566812  tt9916848  tvEpisode              Episode #3.17
# 9566813  tt9916850  tvEpisode              Episode #3.19
# 9566814  tt9916852  tvEpisode              Episode #3.20
# 9566815  tt9916856      short                   The Wind
# 9566816  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9566812              Episode #3.17       0      2010     NaN             \N
# 9566813              Episode #3.19       0      2010     NaN             \N
# 9566814              Episode #3.20       0      2010     NaN             \N
# 9566815                   The Wind       0      2015     NaN             27
# 9566816  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9566812         Action,Drama,Family
# 9566813         Action,Drama,Family
# 9566814         Action,Drama,Family
# 9566815                       Short
# 9566816  Adventure,Animation,Comedy
#
# [9566796 rows x 9 columns]

# %%
title_basics['runtimeMinutes'] = title_basics['runtimeMinutes'].replace({'\\N':np.nan})
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9566812  tt9916848  tvEpisode              Episode #3.17
# 9566813  tt9916850  tvEpisode              Episode #3.19
# 9566814  tt9916852  tvEpisode              Episode #3.20
# 9566815  tt9916856      short                   The Wind
# 9566816  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9566812              Episode #3.17       0      2010     NaN            NaN
# 9566813              Episode #3.19       0      2010     NaN            NaN
# 9566814              Episode #3.20       0      2010     NaN            NaN
# 9566815                   The Wind       0      2015     NaN             27
# 9566816  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9566812         Action,Drama,Family
# 9566813         Action,Drama,Family
# 9566814         Action,Drama,Family
# 9566815                       Short
# 9566816  Adventure,Animation,Comedy
#
# [9566796 rows x 9 columns]

# %%
title_basics['genres'] = title_basics['genres'].replace({'\\N':np.nan})
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9566812  tt9916848  tvEpisode              Episode #3.17
# 9566813  tt9916850  tvEpisode              Episode #3.19
# 9566814  tt9916852  tvEpisode              Episode #3.20
# 9566815  tt9916856      short                   The Wind
# 9566816  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9566812              Episode #3.17       0      2010     NaN            NaN
# 9566813              Episode #3.19       0      2010     NaN            NaN
# 9566814              Episode #3.20       0      2010     NaN            NaN
# 9566815                   The Wind       0      2015     NaN             27
# 9566816  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9566812         Action,Drama,Family
# 9566813         Action,Drama,Family
# 9566814         Action,Drama,Family
# 9566815                       Short
# 9566816  Adventure,Animation,Comedy
#
# [9566796 rows x 9 columns]

# %%
title_basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear               0
# endYear           9464993
# runtimeMinutes    6785215
# genres             434196
# dtype: int64

# %%
title_basics = title_basics.drop(columns=['endYear'])
title_basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear               0
# runtimeMinutes    6785215
# genres             434196
# dtype: int64

# %%
title_basics.dropna(subset=['runtimeMinutes'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst                0
# titleType             0
# primaryTitle          0
# originalTitle         0
# isAdult               0
# startYear             0
# runtimeMinutes        0
# genres            75331
# dtype: int64

# %%
title_basics.dropna(subset=['genres'], inplace=True)
title_basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %% [markdown]
# Eliminate movies that include "Documentary" in genre

# %%
#Eliminate movies that include "Documentary" in genre
is_documentary = title_basics['genres'].str.contains('documentary',case=False)
title_basics= title_basics[~is_documentary]

# %%
title_basics
# Out:
#             tconst  titleType                     primaryTitle  \
# 1        tt0000002      short           Le clown et ses chiens
# 2        tt0000003      short                   Pauvre Pierrot
# 3        tt0000004      short                      Un bon bock
# 4        tt0000005      short                 Blacksmith Scene
# 5        tt0000006      short                Chinese Opium Den
# ...            ...        ...                              ...
# 9566740  tt9916692    tvMovie  Teatroteka: Czlowiek bez twarzy
# 9566773  tt9916766  tvEpisode                   Episode #10.15
# 9566808  tt9916840  tvEpisode       Horrid Henry's Comic Caper
# 9566815  tt9916856      short                         The Wind
# 9566816  tt9916880  tvEpisode        Horrid Henry Knows It All
#
#                            originalTitle isAdult startYear runtimeMinutes  \
# 1                 Le clown et ses chiens       0      1892              5
# 2                         Pauvre Pierrot       0      1892              4
# 3                            Un bon bock       0      1892             12
# 4                       Blacksmith Scene       0      1893              1
# 5                      Chinese Opium Den       0      1894              1
# ...                                  ...     ...       ...            ...
# 9566740  Teatroteka: Czlowiek bez twarzy       0      2015             66
# 9566773                   Episode #10.15       0      2019             43
# 9566808       Horrid Henry's Comic Caper       0      2014             11
# 9566815                         The Wind       0      2015             27
# 9566816        Horrid Henry Knows It All       0      2014             10
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9566740                        Drama
# 9566773  Family,Game-Show,Reality-TV
# 9566808   Adventure,Animation,Comedy
# 9566815                        Short
# 9566816   Adventure,Animation,Comedy
#
# [2309811 rows x 8 columns]

# %% [markdown]
# Keep only US movies

# %%
keepers =title_basics['tconst'].isin(title_akas['titleId'])
keepers
# Out:
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
#            ...
# 9566740     True
# 9566773     True
# 9566808    False
# 9566815     True
# 9566816    False
# Name: tconst, Length: 2309811, dtype: bool

# %%
title_basics = title_basics[keepers]
title_basics
# Out:
#             tconst  titleType                     primaryTitle  \
# 1        tt0000002      short           Le clown et ses chiens
# 2        tt0000003      short                   Pauvre Pierrot
# 3        tt0000004      short                      Un bon bock
# 4        tt0000005      short                 Blacksmith Scene
# 5        tt0000006      short                Chinese Opium Den
# ...            ...        ...                              ...
# 9566703  tt9916610      short                      Private Eye
# 9566705  tt9916616      short                           Terror
# 9566740  tt9916692    tvMovie  Teatroteka: Czlowiek bez twarzy
# 9566773  tt9916766  tvEpisode                   Episode #10.15
# 9566815  tt9916856      short                         The Wind
#
#                            originalTitle isAdult startYear runtimeMinutes  \
# 1                 Le clown et ses chiens       0      1892              5
# 2                         Pauvre Pierrot       0      1892              4
# 3                            Un bon bock       0      1892             12
# 4                       Blacksmith Scene       0      1893              1
# 5                      Chinese Opium Den       0      1894              1
# ...                                  ...     ...       ...            ...
# 9566703                      Private Eye       0      2019             22
# 9566705                           Terror       0        \N             13
# 9566740  Teatroteka: Czlowiek bez twarzy       0      2015             66
# 9566773                   Episode #10.15       0      2019             43
# 9566815                         The Wind       0      2015             27
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9566703         Drama,Mystery,Sci-Fi
# 9566705                  Drama,Short
# 9566740                        Drama
# 9566773  Family,Game-Show,Reality-TV
# 9566815                        Short
#
# [1894881 rows x 8 columns]

# %% [markdown]
# keep only titleType==Movie

# %%
#Eliminate movies that include "short" in genre
is_short = title_basics['titleType'].str.contains('short',case=False)
title_basics= title_basics[~is_short]

#Eliminate movies that include "tvEpisode	" in genre
is_tvEpisode = title_basics['titleType'].str.contains('tvEpisode',case=False)
title_basics= title_basics[~is_tvEpisode]

#Eliminate movies that include "tvSeries" in genre
is_tvSeries = title_basics['titleType'].str.contains('tvSeries',case=False)
title_basics= title_basics[~is_tvSeries]

#Eliminate movies that include "tvMovie" in genre
is_tvMovie = title_basics['titleType'].str.contains('tvMovie',case=False)
title_basics= title_basics[~is_tvMovie]

#Eliminate movies that include "video" in genre
is_video = title_basics['titleType'].str.contains('video',case=False)
title_basics= title_basics[~is_video]

# %%
title_basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 930      tt0000941     movie                  Locura de amor
# ...            ...       ...                             ...
# 9566490  tt9916170     movie                   The Rehearsal
# 9566499  tt9916190     movie                       Safeguard
# 9566538  tt9916270     movie        Il talento del calabrone
# 9566583  tt9916362     movie                           Coven
# 9566667  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult startYear runtimeMinutes  \
# 8                            Miss Jerry       0      1894             45
# 570         The Story of the Kelly Gang       0      1906             70
# 587                   L'enfant prodigue       0      1907             90
# 672      The Fairylogue and Radio-Plays       0      1908            120
# 930                      Locura de amor       0      1909             45
# ...                                 ...     ...       ...            ...
# 9566490                        O Ensaio       0      2019             51
# 9566499                       Safeguard       0      2020             95
# 9566538        Il talento del calabrone       0      2020             84
# 9566583                        Akelarre       0      2020             92
# 9566667             Kuambil Lagi Hatiku       0      2019            123
#
#                              genres
# 8                           Romance
# 570      Action,Adventure,Biography
# 587                           Drama
# 672               Adventure,Fantasy
# 930                           Drama
# ...                             ...
# 9566490                       Drama
# 9566499   Action,Adventure,Thriller
# 9566538                    Thriller
# 9566583               Drama,History
# 9566667                       Drama
#
# [311228 rows x 8 columns]

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311228 entries, 8 to 9566667
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          311228 non-null  object
#  1   titleType       311228 non-null  object
#  2   primaryTitle    311228 non-null  object
#  3   originalTitle   311228 non-null  object
#  4   isAdult         311228 non-null  object
#  5   startYear       311228 non-null  object
#  6   runtimeMinutes  311228 non-null  object
#  7   genres          311228 non-null  object
# dtypes: object(8)
# memory usage: 21.4+ MB

# %%
## Save current dataframe to file.
title_basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [23], line 2
#       1 ## Save current dataframe to file.
# ----> 2 title_basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Data'

# %%
# Open saved file and preview again
title_basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
title_basics.head()
